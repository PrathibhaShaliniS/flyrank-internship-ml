# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PrathibhaShaliniS/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I choose the CTR /Engagement opportunity scoring lane because if focuses on identifying which content has the greatest opportunity to improve user engagement.The goal is to use the data to decide which pages or content should be optimized.

# %%
print("My lane: CTR/Engagement.")
# Out:
# My lane: CTR/Engagement.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Which wedpages have the best chance to improve CTR and user engagement?
# Decision:Decide which webpages should be improved first.
# action:Promote those webpages to get more user clicks.
# Cost of wrong recommendation:If the recommendation is wrong ,time and effort may be wasted on the wrong webpages,while better pages and ignored.

# %%
print("Research Question:Which webpages have the best chance to improve CTR and user Engagement? ")
print("Decision:Decide which webpages should be improved first.")
print("Action:Promote those webpages to get more user clicks.")
print("Cost of wrong recommendation:If the recommendation is wrong,time and effort may be wasted on the wrong webpages,while better pages and ignored.")
# Out:
# Research Question:Which webpages have the best chance to improve CTR and user Engagement?
# Decision:Decide which webpages should be improved first.
# Action:Promote those webpages to get more user clicks.
# Cost of wrong recommendation:If the recommendation is wrong,time and effort may be wasted on the wrong webpages,while better pages and ignored.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# I explored the starter dataset and found that it contains 30000 rows and 44 columns.This dataset is large enough to analyze CTR and engagement opportunities.These numbers show that there is enough information to identify which webpages should be improved first.

# %%
rows=30000
columns=44
print("Number of rows:",rows)
print("Number of columns:",columns)
print("The dataset is suitable foe CTR and engagement analysis.")
# Out:
# Number of rows: 30000
# Number of columns: 44
# The dataset is suitable foe CTR and engagement analysis.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work can identify webpages that may have better CTR and engagement opportunities based on the available data.It provides recommendations to help make better decisions,but it cannot prove that improving a webpages will definitly increase clicks.

# %%
print("My analysis provides decision support based on the dataset.")
print("It cannot guarantee higher CTR.")
# Out:
# My analysis provides decision support based on the dataset.
# It cannot guarantee higher CTR.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
