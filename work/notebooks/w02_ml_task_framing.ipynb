# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PrathibhaShaliniS/flyrank-internship-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My Lane as an ML Task
#
# I chose the CTR (Click-Through Rate) / Engagement Opportunity Scoring lane because it predicts how likely users are to click on content. CTR is based on user clicks and impressions, making it a useful measure of user engagement. The goal of this lane is to identify and rank content that is most likely to receive user clicks, helping improve user engagement and content performance.
#
# This is a scoring manchine learning task because the model predicts a CTR or engagement score for each content item.The predicted scores are used to rank content so that users are shown the items they are most likely to click and engage with.This helps improve user engagement and content performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
lane="CTR/Engagement Opportunity scoring"
task_type="scoring"
print("Lane:",lane )
print("ML Task Type:",task_type)
# Out:
# Lane: CTR/Engagement Opportunity scoring
# ML Task Type: scoring

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target:Predict the Click-Through Rate interest and engagement score for each content item.
# Proxy:CTR acts as aproxy for user interest and engagement because higher CTR usually indicates that users find the content relevant.
# The target comes from observed outcomes, such as actual user clicks and impressions collected from historical data, rather than from a manually defined rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Target (What the model Predicts)
target ="Click Through Rate (CTR)"
label_source="Observed user clicks and impressions"
print("Target:",target)
print("Label source:",label_source)
# Out:
# Target: Click Through Rate (CTR)
# Label source: Observed user clicks and impressions

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The model is successful if it correctly predicts which content is more likely to receive clicks and engagement.A good model should rank high-engagement content above low-engagement content.
# For example: If Article A receives more user clicks than Article B, the model should assign a higher score to Article A and rank it above Article B.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
success_metric ="Rank high CTR /Engagement content correctly"
print("success Metric:" ,success_metric)
# Out:
# success Metric: Rank high CTR /Engagement content correctly

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One rows represents one content item (such as an article or webpages) along with its features,impressions,clicks and other information used to predict itsCTR or engagement score.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("One row represents one content item.")
#example unit analysis
content={
    "Article":"AI Basics",
    "Impressions":1000,
    "Clicks":120
}
print(content)
# Out:
# One row represents one content item.
# {'Article': 'AI Basics', 'Impressions': 1000, 'Clicks': 120}

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Machine learning is better than a fixed rule because user engagement dapends on many fcators ,such as user interests,content quality,keywords,and previous interactions.A fixed rule cannot capture these complex patterns,while a machine learning model can learn from historical data and make accurate predicitions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
reason="ML learn complex patterns better than a fixed rule."
print(reason)
# Out:
# ML learn complex patterns better than a fixed rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
